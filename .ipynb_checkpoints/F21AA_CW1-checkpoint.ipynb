# %% [markdown]
# # pip installs if needed.

# %%
pip install seaborn

# %%
pip install lxml

# %%
pip install bs4

# %%
pip install spacy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading Reviews to Dataframe...
print('Loading reviews...',end='')
df = pd.read_csv('train.csv')
print('[ok]')
print('Loaded {:,} reviews' .format(len(df)))
# Out:
# Loading reviews...[ok]
# Loaded 426,340 reviews

# %% [markdown]
# # 1- Data Exploration and Visualization: (10%)
# Provide an initial step to inspect, visualize and analyse the different attributes in your data set.
# Document your findings and make conclusions for your next steps

# %%
df.columns #Deciding on Columns we might need, dropping the rest for now
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df.head()
# Out:
#        Id   ProductId          UserId                      ProfileName  \
# 0  220291  B0034EDLS2   AVF82BC7S0IO7                           Kbrown
# 1  225833  B001I7HJE4  A1YUL9PCJR3JTY  O. Brown "Ms. O. Khannah-Brown"
# 2  350901  B000LKTB90  A1BBPP1EC75JX4           Johan Bollen "gekhond"
# 3  299801  B001HXJPS2   A5QSI9MNS8NMS                        M. Esaili
# 4   48472  B006H34CUS  A20IBAIRSNBEAQ                          Chelsea
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     0                       0      5  1332806400
# 1                     1                       1      5  1190160000
# 2                     0                       0      5  1285977600
# 3                     0                       0      5  1338163200
# 4                     0                       0      5  1343606400
#
#                                              Summary  \
# 0                                          Very Good
# 1  Organic, Kosher, Tasty Assortment of Premium T...
# 2  excellent gluten-free spaghetti: great taste, ...
# 3                                     Lindt is Lindt
# 4                                           YUM!!!!!
#
#                                                 Text
# 0  I received this product early from the seller!...
# 1  *****<br />Numi's Collection Assortment Melang...
# 2  I was very careful not to overcook this pasta,...
# 3  Buying this multi-pack I was misled by the pic...
# 4  These bars are so good! I loved them warmed up...

# %%
df.tail()
# Out:
#             Id   ProductId          UserId      ProfileName  \
# 426335  209346  B00028LDJ2  A28AJSK2CI1XAO         K. Saito
# 426336  494704  B000BZZKVS   ACHJKSYDTDKMU   Justin P. Owen
# 426337   12798  B000U0HJMC  A3A7T94SGEKY8A  Mary A. Earhart
# 426338  293826  B000NCW0BC  A3B2BB1JFBNAX5     Linda Cooper
# 426339  366218  B001D9JC0G  A3KZG8XNX5P4HR       D. Dunstan
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 426335                     1                       1      3  1203379200
# 426336                     3                       4      5  1247702400
# 426337                     2                       2      5  1231286400
# 426338                     0                       0      5  1344124800
# 426339                     6                       7      1  1219104000
#
#                                             Summary  \
# 426335                                    i like it
# 426336                             The Anti-Fatigue
# 426337                     Always the right formula
# 426338                          Smoked Black Pepper
# 426339  Canidae Dog Food made my dogs extremely ill
#
#                                                      Text
# 426335  Like a lot of the gums by Lotte, the flavor do...
# 426336  This is a fantastic product.  I'm relatively n...
# 426337  I trust this brand--the flavors are blended ju...
# 426338  This pepper is great! I was buying McCormick, ...
# 426339  I have relied on Canidae for my 4 dogs for ove...

# %%
df.describe(include='all')
# Out:
#                    Id   ProductId          UserId       ProfileName  \
# count   426340.000000      426340          426340            426326
# unique            NaN       65858          210008            180746
# top               NaN  B007JFMH8M  A3OXHLG6DIBRW8  C. F. Hill "CFH"
# freq              NaN         667             326               329
# mean    284300.799618         NaN             NaN               NaN
# std     164012.600602         NaN             NaN               NaN
# min          1.000000         NaN             NaN               NaN
# 25%     142363.750000         NaN             NaN               NaN
# 50%     284308.500000         NaN             NaN               NaN
# 75%     426183.250000         NaN             NaN               NaN
# max     568454.000000         NaN             NaN               NaN
#
#         HelpfulnessNumerator  HelpfulnessDenominator          Score  \
# count          426340.000000           426340.000000  426340.000000
# unique                   NaN                     NaN            NaN
# top                      NaN                     NaN            NaN
# freq                     NaN                     NaN            NaN
# mean                1.733159                2.220244       4.183455
# std                 7.328184                8.014894       1.310577
# min                 0.000000                0.000000       1.000000
# 25%                 0.000000                0.000000       4.000000
# 50%                 0.000000                1.000000       5.000000
# 75%                 2.000000                2.000000       5.000000
# max               844.000000              923.000000       5.000000
#
#                 Time     Summary  \
# count   4.263400e+05      426320
# unique           NaN      235299
# top              NaN  Delicious!
# freq             NaN        1824
# mean    1.296222e+09         NaN
# std     4.808061e+07         NaN
# min     9.408096e+08         NaN
# 25%     1.271203e+09         NaN
# 50%     1.311034e+09         NaN
# 75%     1.332720e+09         NaN
# max     1.351210e+09         NaN
#
#                                                      Text
# count                                              426340
# unique                                             308249
# top     This review will make me sound really stupid, ...
# freq                                                  140
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
print("Skewness: %f" % df['Score'].skew())
print("Kurtosis: %f" % df['Score'].kurt())
# Out:
# Skewness: -1.461055
# Kurtosis: 0.750572

# %%
print(df.nunique())
# Out:
# Id                        426340
# ProductId                  65858
# UserId                    210008
# ProfileName               180746
# HelpfulnessNumerator         215
# HelpfulnessDenominator       221
# Score                          5
# Time                        3099
# Summary                   235299
# Text                      308249
# dtype: int64

# %%
print(df.shape)
# Out:
# (426340, 10)

# %%
print("\nSCORE 5: \n" + str(df[df['Score'] == 5].count()))
print("\nSCORE 4: \n" + str(df[df['Score'] == 4].count()))
print("\nSCORE 3: \n" + str(df[df['Score'] == 3].count()))
print("\nSCORE 2: \n" + str(df[df['Score'] == 2].count()))
print("\nSCORE 1: \n" + str(df[df['Score'] == 1].count()))
# Out:
# SCORE 5:
# Id                        272492
# ProductId                 272492
# UserId                    272492
# ProfileName               272482
# HelpfulnessNumerator      272492
# HelpfulnessDenominator    272492
# Score                     272492
# Time                      272492
# Summary                   272492
# Text                      272492
# dtype: int64
#
# SCORE 4:
# Id                        60309
# ProductId                 60309
# UserId                    60309
# ProfileName               60309
# HelpfulnessNumerator      60309
# HelpfulnessDenominator    60309
# Score                     60309
# Time                      60309
# Summary                   60309
# Text                      60309
# dtype: int64
#
# SCORE 3:
# Id                        31993
# ProductId                 31993
# UserId                    31993
# ProfileName               31993
# HelpfulnessNumerator      31993
# HelpfulnessDenominator    31993
# Score                     31993
# Time                      31993
# Summary                   31991
# Text                      31993
# dtype: int64
#
# SCORE 2:
# Id                        22353
# ProductId                 22353
# UserId                    22353
# ProfileName               22353
# HelpfulnessNumerator      22353
# HelpfulnessDenominator    22353
# Score                     22353
# Time                      22353
# Summary                   22335
# Text                      22353
# dtype: int64
#
# SCORE 1:
# Id                        39193
# ProductId                 39193
# UserId                    39193
# ProfileName               39189
# HelpfulnessNumerator      39193
# HelpfulnessDenominator    39193
# Score                     39193
# Time                      39193
# Summary                   39193
# Text                      39193
# dtype: int64

# %%
df.hist()
# We need to comment on the graph below, Basically the data is biased towards score 5 .
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x2AA47B50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x2AA64E30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x2AA84FB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x2AAAE630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x2AAD1710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x2C0907F0>]],
#       dtype=object)

# %%
col_names = ['Id','UserId','ProfileName','HelpfulnessNumerator','HelpfulnessDenominator','Time','ProductId']
analysis_df = df
numeric_col_names = analysis_df.select_dtypes(include=np.number).columns.tolist()

fig, ax = plt.subplots(len(numeric_col_names), figsize=(16,12))

for i, col_val in enumerate(numeric_col_names):

    sns.distplot(analysis_df[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)

plt.show()

# %%
sns.pairplot(df)

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
df.groupby('Score').describe()
# Out:
#              Id                                                          \
#           count           mean            std   min       25%       50%
# Score
# 1       39193.0  282904.535606  162865.104452   2.0  142706.0  283604.0
# 2       22353.0  280643.847850  164445.543153  68.0  137929.0  278032.0
# 3       31993.0  279476.092333  165426.046308  46.0  136097.0  274969.0
# 4       60309.0  281941.848729  164780.725409   3.0  138600.0  280352.0
# 5      272492.0  285890.169021  163781.498091   1.0  144535.5  287247.5
#
#                           HelpfulnessNumerator            ...  \
#             75%       max                count      mean  ...
# Score                                                     ...
# 1      421880.0  568434.0              39193.0  2.747812  ...
# 2      422521.0  568451.0              22353.0  1.864627  ...
# 3      424951.0  568423.0              31993.0  1.733817  ...
# 4      424999.0  568421.0              60309.0  1.379910  ...
# 5      427344.5  568454.0             272492.0  1.654540  ...
#
#       HelpfulnessDenominator             Time                              \
#                          75%    max     count          mean           std
# Score
# 1                        6.0  486.0   39193.0  1.303158e+09  4.333798e+07
# 2                        3.0  536.0   22353.0  1.301144e+09  4.455342e+07
# 3                        2.0  923.0   31993.0  1.300218e+09  4.477022e+07
# 4                        2.0  462.0   60309.0  1.296626e+09  4.807909e+07
# 5                        2.0  815.0  272492.0  1.294262e+09  4.921788e+07
#
#
#                min           25%           50%           75%           max
# Score
# 1      948240000.0  1.286237e+09  1.316909e+09  1.334275e+09  1.351210e+09
# 2      992217600.0  1.282954e+09  1.314662e+09  1.333757e+09  1.351210e+09
# 3      990921600.0  1.280362e+09  1.313712e+09  1.333411e+09  1.351210e+09
# 4      951523200.0  1.271290e+09  1.312070e+09  1.333325e+09  1.351210e+09
# 5      940809600.0  1.267142e+09  1.309046e+09  1.332029e+09  1.351210e+09
#
# [5 rows x 32 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               14
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   20
# Text                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
def percentile_based_outlier(data, threshold=95):
    diff = (100 - threshold) / 2
    minval, maxval = np.percentile(data, [diff, 100 - diff])
    return (data < minval) | (data > maxval)

col_names = ['Id','UserId','ProfileName','HelpfulnessNumerator','HelpfulnessDenominator','Time','ProductId']
numeric_col_names = analysis_df.select_dtypes(include=np.number).columns.tolist()

fig, ax = plt.subplots(len(numeric_col_names), figsize=(8,40))

for i, col_val in enumerate(numeric_col_names):
    x = df[col_val][:1000]
    sns.distplot(x, ax=ax[i], rug=True, hist=False)
    outliers = x[percentile_based_outlier(x)]
    ax[i].plot(outliers, np.zeros_like(outliers), 'ro', clip_on=False)

    ax[i].set_title('Outlier detection - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %%
""" 
We Found relatively Small number of NAN onject in the dataset  in both TEXT and Summary features
wE will replace with '' and drop the UN-NEEDED columns for now
"""
df.Summary.fillna('', inplace=True)
df.Text.fillna('', inplace=True)
df.drop(['Id','UserId','ProfileName','HelpfulnessNumerator','HelpfulnessDenominator','Time','ProductId'],axis=1,inplace=True)

# %%
#Concatinating TEXT and Summary features as per the DR. example. Which is OK as I didnt find obvious correlation
df['text']=df['Summary']+' '+df['Text'] 
df.drop(['Summary','Text'],axis=1,inplace=True)
df['length']=df['text'].str.len()

# %%
df.hist(column='length',by='Score',bins=200,figsize=(8,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x2C6A2410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x2C13D410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x3EF8BCF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3EFADDD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x3EECDEB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3EED9F90>]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Score', 'text', 'length'], dtype='object')

# %%
# We can conclude from the table above, that the distributions is not equal, text with ratings 5 are far more than any other score

# %%
# We need to write the conclustion for the graph
#ALso feel free to add whatever graph you like so we can visualize the data as much as we can
# DataFrame is called df , you can see its columns by running df.columns for more info run  df.info(), df.describe() ...etc

# %% [markdown]
# # 2 - Text Processing and Normalization: (20%)
# Thoroughly experiment with different text processing and normalization alternatives. Explain the
# trade-off and benefits of using each and justify their effectiveness for the current data set.

# %% [markdown]
# """
# NOTE FOR THE TEAM
# This question (Question 2) is all about text normalization (tokenization) , this includes
# cleaning the text and make it uniform, this is mainly done via removing punctuations, stopword
# After our call, I noticed some html tags in the text, we need to remove them as well.
# The catch is they MUST be removed before the pre-processing function , the reason is once we use the function, we loose punctuations,
# so <br> looks like br , so we cant really figure out that it was in fact and HTML tag.
# SO I will work on creating a fn to clean the html tags first, then pass it to the tokenization function
# """

# %% [markdown]
# """
# Update, I found a libraries that can do that, you need to install
# pip install lxml
# pip install beautifulsoup4
# Added them to the tokenizer function
# """

# %%
# We will use 2 methods to tokeinze the corpse...stemming and Lemmatization , both from NLTK librarry

#Once we finzalie the analysis, we will use CV and TFIDF to vectorize then build the pipeline with either one of them (cant have both in pipline AFAIK)
# (possibly we will use TFIDF)

#UPDATE, we will only remove the html tags and puncations ( we wont test that i believe as this will make the model better)

# %%
#Method 1 - Building our own tokenizer (to remove HTML and punc)

# %%
import string,lxml,bs4

# %%
string.punctuation # we will remove this
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#This function will remove html tags, punctiaton [Must run in order ]
def tokenizer(text):
    no_html = bs4.BeautifulSoup(text,'lxml').get_text()
    no_punctuation = [char for char in no_html if char not in string.punctuation]
    no_punctuation = ''.join(no_punctuation)
    return no_punctuation

# %%
df_original = df.copy() #Backup to work on raw input data if we will need it later...

# %% [markdown]
# ### Stratification - Subset of Data Set (10,000)

# %%
def stratified_sample_df(df, col, n_samples):
    n = min(n_samples, df[col].value_counts().min())
    df_ = df.groupby(col).apply(lambda x: x.sample(n))
    df_.index = df_.reset_index(drop=True)
    return df_

# %%
stratified_sample_df = stratified_sample_df(df_original, 'Score', 10000)

# %%
# IMPORTNAT... THIS IS CREATING A SMALLER SUBSET OF DATA, REMOVE THIS LINE TO WORK ON ALL DATA
df = df.head(1000)
print ( 'Original DB size is',len(df_original),' Current db size',len(df))

# %%
#stratified sub sample (10,000)
stratified_sample_df.head(10)
# Out:
#                                                     Score  \
# (1, herbal tee, no caffeine Pleasant, no caffei...      1
# (1, Worst Possible Choice Of Rawhide Nature's C...      1
# (1, $8 price jump? i've been paying $39.99 for ...      1
# (1, Contains BPA I am absolutely shocked to lea...      1
# (1, Terrible I expect my dark roast to be exact...      1
# (1, Turns into plastic Bought vanilla and choco...      1
# (1, Our cats threw up in pain after eating this...      1
# (1, shipping really high - buy at Wegman's This...      1
# (1, Toasted Corn and Rice for Cats! I was given...      1
# (1, only one pack If you buy this, only one pac...      1
#
#                                                                                                  text  \
# (1, herbal tee, no caffeine Pleasant, no caffei...  herbal tee, no caffeine Pleasant, no caffeine ...
# (1, Worst Possible Choice Of Rawhide Nature's C...  Worst Possible Choice Of Rawhide Nature's Choi...
# (1, $8 price jump? i've been paying $39.99 for ...  $8 price jump? i've been paying $39.99 for thi...
# (1, Contains BPA I am absolutely shocked to lea...  Contains BPA I am absolutely shocked to learn ...
# (1, Terrible I expect my dark roast to be exact...  Terrible I expect my dark roast to be exactly ...
# (1, Turns into plastic Bought vanilla and choco...  Turns into plastic Bought vanilla and chocolat...
# (1, Our cats threw up in pain after eating this...  Our cats threw up in pain after eating this fo...
# (1, shipping really high - buy at Wegman's This...  shipping really high - buy at Wegman's This pr...
# (1, Toasted Corn and Rice for Cats! I was given...  Toasted Corn and Rice for Cats! I was given a ...
# (1, only one pack If you buy this, only one pac...  only one pack If you buy this, only one pack w...
#
#                                                     length
# (1, herbal tee, no caffeine Pleasant, no caffei...     177
# (1, Worst Possible Choice Of Rawhide Nature's C...     398
# (1, $8 price jump? i've been paying $39.99 for ...     196
# (1, Contains BPA I am absolutely shocked to lea...     263
# (1, Terrible I expect my dark roast to be exact...     262
# (1, Turns into plastic Bought vanilla and choco...     674
# (1, Our cats threw up in pain after eating this...     681
# (1, shipping really high - buy at Wegman's This...     582
# (1, Toasted Corn and Rice for Cats! I was given...    1671
# (1, only one pack If you buy this, only one pac...     140

# %%
#shuffle the data
from sklearn.utils import shuffle
shuf_and_strat_df = shuffle(stratified_sample_df)

# %%
shuf_and_strat_df.describe(include='all')
# Out:
#                Score                                               text  \
# count   50000.000000                                              50000
# unique           NaN                                              44117
# top              NaN  Filler food is empty, leaves your cat always n...
# freq             NaN                                                 28
# mean        3.000000                                                NaN
# std         1.414228                                                NaN
# min         1.000000                                                NaN
# 25%         2.000000                                                NaN
# 50%         3.000000                                                NaN
# 75%         4.000000                                                NaN
# max         5.000000                                                NaN
#
#               length
# count   50000.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      500.558660
# std       477.542542
# min        55.000000
# 25%       218.000000
# 50%       363.000000
# 75%       614.000000
# max     21535.000000

# %%
df['text'] = df['text'].apply(tokenizer)

# %%
shuf_and_strat_df['text'] = shuf_and_strat_df['text'].apply(tokenizer)

# %%
shuf_and_strat_df.head()
# Out:
#                                                     Score  \
# (2, Not impressed I probably would have liked t...      2
# (1, Way Overpriced The cost per cup is much hig...      1
# (5, True, rich colors made easy Upgraded to thi...      5
# (4, disappointed it isn't hazelnut CREAM decaf ...      4
# (1, Green Fuzzy Jerky After paying extra to sen...      1
#
#                                                                                                  text  \
# (2, Not impressed I probably would have liked t...  Not impressed I probably would have liked thes...
# (1, Way Overpriced The cost per cup is much hig...  Way Overpriced The cost per cup is much higher...
# (5, True, rich colors made easy Upgraded to thi...  True rich colors made easy Upgraded to this th...
# (4, disappointed it isn't hazelnut CREAM decaf ...  disappointed it isnt hazelnut CREAM decaf The ...
# (1, Green Fuzzy Jerky After paying extra to sen...  Green Fuzzy Jerky After paying extra to send t...
#
#                                                     length
# (2, Not impressed I probably would have liked t...     884
# (1, Way Overpriced The cost per cup is much hig...     135
# (5, True, rich colors made easy Upgraded to thi...     332
# (4, disappointed it isn't hazelnut CREAM decaf ...     291
# (1, Green Fuzzy Jerky After paying extra to sen...     315

# %% [markdown]
# ### Stemming

# %% [markdown]
# Porter Stemmer

# %%
df_PS = df.copy()

# %%
df_PS = shuf_and_strat_df.copy()

# %%
from nltk.stem import PorterStemmer

# %%
nltkstemmer = PorterStemmer()

# %%
def stemmer(text):
    review = [nltkstemmer.stem(word) for word in text.split()]
    review = ' '.join(review) 
    return review

# %%
df_PS['text']= df_PS['text'].apply(stemmer)

# %%
df_PS.head()
# Out:
#                                                     Score  \
# (2, Not impressed I probably would have liked t...      2
# (1, Way Overpriced The cost per cup is much hig...      1
# (5, True, rich colors made easy Upgraded to thi...      5
# (4, disappointed it isn't hazelnut CREAM decaf ...      4
# (1, Green Fuzzy Jerky After paying extra to sen...      1
#
#                                                                                                  text  \
# (2, Not impressed I probably would have liked t...  not impress I probabl would have like these be...
# (1, Way Overpriced The cost per cup is much hig...  way overpr the cost per cup is much higher tha...
# (5, True, rich colors made easy Upgraded to thi...  true rich color made easi upgrad to thi the ki...
# (4, disappointed it isn't hazelnut CREAM decaf ...  disappoint it isnt hazelnut cream decaf the pi...
# (1, Green Fuzzy Jerky After paying extra to sen...  green fuzzi jerki after pay extra to send thi ...
#
#                                                     length
# (2, Not impressed I probably would have liked t...     884
# (1, Way Overpriced The cost per cup is much hig...     135
# (5, True, rich colors made easy Upgraded to thi...     332
# (4, disappointed it isn't hazelnut CREAM decaf ...     291
# (1, Green Fuzzy Jerky After paying extra to sen...     315

# %% [markdown]
# Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
nltkstemmer = SnowballStemmer(language='english')

# %%
df_PS['text']= df_PS['text'].apply(stemmer)

# %%
df_PS.head()
# Out:
#                                                     Score  \
# (2, Not impressed I probably would have liked t...      2
# (1, Way Overpriced The cost per cup is much hig...      1
# (5, True, rich colors made easy Upgraded to thi...      5
# (4, disappointed it isn't hazelnut CREAM decaf ...      4
# (1, Green Fuzzy Jerky After paying extra to sen...      1
#
#                                                                                                  text  \
# (2, Not impressed I probably would have liked t...  not impress i probabl would have like these be...
# (1, Way Overpriced The cost per cup is much hig...  way overpr the cost per cup is much higher tha...
# (5, True, rich colors made easy Upgraded to thi...  true rich color made easi upgrad to this the k...
# (4, disappointed it isn't hazelnut CREAM decaf ...  disappoint it isnt hazelnut cream decaf the pi...
# (1, Green Fuzzy Jerky After paying extra to sen...  green fuzzi jerki after pay extra to send this...
#
#                                                     length
# (2, Not impressed I probably would have liked t...     884
# (1, Way Overpriced The cost per cup is much hig...     135
# (5, True, rich colors made easy Upgraded to thi...     332
# (4, disappointed it isn't hazelnut CREAM decaf ...     291
# (1, Green Fuzzy Jerky After paying extra to sen...     315

# %% [markdown]
# ### Lemmatizing

# %% [markdown]
# Word Net Lemmatizer

# %%
df_LM = df.copy()

# %%
df_LM = shuf_and_strat_df.copy()

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltklem = WordNetLemmatizer()

# %%
def lemmatizer(text):
    # decided to go with option v, not n for no obvoius reason except my surface laptop is burning hot :)!
    review = [nltklem.lemmatize(word,'v') for word in text.lower().split()]
    review = ' '.join(review)
    #print(review)
    return review

# %%
df_LM['text'] = df_LM['text'].apply(lemmatizer)

# %%
df_LM.head()
# Out:
#                                                     Score  \
# (2, Not impressed I probably would have liked t...      2
# (1, Way Overpriced The cost per cup is much hig...      1
# (5, True, rich colors made easy Upgraded to thi...      5
# (4, disappointed it isn't hazelnut CREAM decaf ...      4
# (1, Green Fuzzy Jerky After paying extra to sen...      1
#
#                                                                                                  text  \
# (2, Not impressed I probably would have liked t...  not impress i probably would have like these b...
# (1, Way Overpriced The cost per cup is much hig...  way overprice the cost per cup be much higher ...
# (5, True, rich colors made easy Upgraded to thi...  true rich color make easy upgrade to this the ...
# (4, disappointed it isn't hazelnut CREAM decaf ...  disappoint it isnt hazelnut cream decaf the pi...
# (1, Green Fuzzy Jerky After paying extra to sen...  green fuzzy jerky after pay extra to send this...
#
#                                                     length
# (2, Not impressed I probably would have liked t...     884
# (1, Way Overpriced The cost per cup is much hig...     135
# (5, True, rich colors made easy Upgraded to thi...     332
# (4, disappointed it isn't hazelnut CREAM decaf ...     291
# (1, Green Fuzzy Jerky After paying extra to sen...     315

# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-76a01d9c502b> in <module>
# ----> 1 import spacy
#
# ModuleNotFoundError: No module named 'spacy'

# %% [markdown]
# #### Comparison of the 3 datasets

# %%
i=15 #set i to the record you wanna see

# %%
df_original['text'].iloc[i]

# %%
df['text'].iloc[i]

# %%
df_PS['text'].loc[i]

# %%
df_LM['text'].loc[i]

# %% [markdown]
# ### Conclusion

# %%
# Write our conclusion here...!

# %% [markdown]
# # Vector space Model and feature representation: (20%)
# Experiment with different representation techniques. Document your findings and make
# conclusions. Show how choosing n-gram features can influence your results

# %% [markdown]
# ### CountVictorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Method1 df | CountVectorizer (defualt 'word' analyzer)

# Fitting 
bow_m1 = CountVectorizer().fit(df['text'])
#Transform 
df_small_bow_m1 = bow_m1.transform(df['text'])

# %%
# Method2 df | CountVectorizer(our custom analyzer aka Tokenizer)

# Fitting 
bow_m2 = CountVectorizer(analyzer=tokenizer).fit(df['text'])
#Transform 
df_small_bow_m2 = bow_m2.transform(df['text'])

# %%
# Method3 df | CountVectorizer(char analyzer)

# Fitting 
bow_m3 = CountVectorizer(analyzer='char').fit(df['text'])
#Transform 
df_small_bow_m3 = bow_m3.transform(df['text'])

# %%
# Method4 df | CountVectorizer(stop words )

# Fitting 
bow_m4 = CountVectorizer(stop_words={'english'},analyzer= 'word',ngram_range=(1,2)).fit(df['text'])
#Transform 
df_small_bow_m4 = bow_m4.transform(df['text'])

# %%
#findings and Results

# %%
print('Method 1 CV')
print('Bag of words CV1',len(bow_m1.vocabulary_))

# %%
print('Method 2 CV')
print('Bag of words CV2',len(bow_m2.vocabulary_))

# %%
print('Method 3 CV')
print('Bag of words CV3',len(bow_m3.vocabulary_))

# %%
print('Method 4 CV')
print('Bag of words CV4',len(bow_m4.vocabulary_))

# %% [markdown]
# ### TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
BOW_TFIDF1 = TfidfVectorizer(stop_words={'english'},ngram_range=(1,2))
BOW_TFIDF1.fit(df['text'])
#BOW_TFIDF1.fit_transform(df_small['text'])

# %%
BOW_TFIDF2 = TfidfVectorizer(analyzer=tokenizer,ngram_range=(1,2))
BOW_TFIDF2.fit(df['text'])
#BOW_TFIDF1.fit_transform(df_small['text'])

# %%
BOW_TFIDF3 = TfidfVectorizer(ngram_range=(1,2),min_df=2)
BOW_TFIDF3.fit(df['text'])
#BOW_TFIDF1.fit_transform(df_small['text'])

# %%
print('Method 1 TFIDF')
print('Bag of words TFIDF1',len(BOW_TFIDF1.vocabulary_))

# %%
print('Method 2 TFIDF')
print('Bag of words TFIDF2',len(BOW_TFIDF2.vocabulary_))

# %%
print('Method 3 TFIDF')
print('Bag of words TFIDF3',len(BOW_TFIDF3.vocabulary_))

# %% [markdown]
# # Model training, selection and hyperparameter tuning and evaluation:(20%)
# You should at least experiment with 3 models and show how you can optimize model
# parameters using cross validation. For each model discuss your choices of text processing,
# representation and features from steps 1-3.
